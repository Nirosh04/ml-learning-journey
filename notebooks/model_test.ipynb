# %%
import requests

data = {
    "Pclass": 3,
    "Sex": "male",     # Achtung: als Text, nicht 0/1 – weil der Encoder das erwartet
    "Age": 22,
    "Fare": 7.25,
    "Embarked": "S"    # Fehlte bisher → jetzt hinzugefügt
}

response = requests.post("http://127.0.0.1:8000/predict", json=data)
print(response.json())
# Out:
# {'prediction': 0.0}
